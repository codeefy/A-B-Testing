# %% [markdown]
# ### A/B Testing

# %% [markdown]
# A/B testing, also known as split testing, is a method of comparing two versions of a webpage or app against each other to determine which one performs better. It involves randomly assigning users to either the control group (version A) or the experimental group (version B) and measuring their interactions with the respective versions. The goal is to identify which version leads to higher conversion rates, user engagement, or other desired outcomes. A/B testing is commonly used in marketing, product development, and user experience design to make data-driven decisions and optimize performance.

# %% [markdown]
# ### Real Life Scenarios

# %% [markdown]
# how ab test work in real life scenarios
#
# suppose if amazon wants to test a new recommendation algorithm on their website, they would use A/B testing to compare the performance of the new algorithm against the existing one.
# Here's how the A/B testing process might work in this scenario:
# 1. **Define the Objective**: Amazon would first define the objective of the A/B test, such as increasing click-through rates on recommended products or improving overall sales.
# 2. **Create Variants**: Amazon would create two versions of their recommendation system: the control group (A) which uses the existing algorithm, and the treatment group (B) which uses the new recommendation algorithm.
# 3. **Random Assignment**: Amazon would randomly assign a portion of their website visitors to either the control group or the treatment group. This ensures that the test results are not biased by any external factors.
# 4. **Collect Data**: As visitors interact with the website, Amazon would collect data on key metrics such as click-through rates, conversion rates, and sales for both groups.
# 5. **Analyze Results**: After a predetermined period, Amazon would analyze the collected data to determine if there is a statistically significant difference between the two groups. They would use statistical tests to assess whether the new recommendation algorithm performs better than the existing one.
# 6. **Make Decisions**: Based on the analysis, Amazon would decide whether to implement the new recommendation algorithm for all users or to stick with the existing one. If the new algorithm shows a significant improvement in performance, it may be rolled out to all users. If not, Amazon may choose to continue using the existing algorithm or iterate on the new one for further testing.
# In real-life scenarios, A/B testing is a powerful tool for making data-driven decisions and optimizing user experiences. It allows companies like Amazon to test new features, designs, or algorithms in a controlled environment before fully implementing them, reducing the risk of negative impacts on user experience and business outcomes.

# %% [markdown]
# ### Optimizing Ad Bidding: Facebook's A/B Test Story

# %% [markdown]
# A/B Testing for the Company's Facebook Advertisements

# %% [markdown]
# ### Problem Statement
#
# "Facebook has recently developed a new bidding system for its advertisements called 'average bidding' (test group) in French, alongside the classic maximum bid known as 'maximum bidding' (control group). The bid determines which advertisement will be presented to the user based on what the advertiser is willing to pay.
#
# With the maximum bid, the advertiser specifies the maximum amount they would be willing to pay for each impression. With the average bid, the advertiser specifies the average amount they would be willing to pay for each impression.
#
# The dataset that will be analyzed later presents the results of these two bidding strategies over 40 days to determine which of the two is better in earning."

# %% [markdown]
# Load the Dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
# Load the data
df_control = pd.read_csv('control_group.csv')
df_test=pd.read_csv('test_group.csv')

# %%
df_control.info()
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Impression  40 non-null     int64
#  1   Click       40 non-null     int64
#  2   Purchase    40 non-null     int64
#  3   Earning     40 non-null     int64
# dtypes: int64(4)
# memory usage: 1.4 KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Impression  40 non-null     int64
#  1   Click       40 non-null     int64
#  2   Purchase    40 non-null     int64
#  3   Earning     40 non-null     int64
# dtypes: int64(4)
# memory usage: 1.4 KB

# %%
df_control.head()
# Out:
#    Impression  Click  Purchase  Earning
# 0       82529   6090       665     2311
# 1       98050   3383       315     1743
# 2       82696   4168       458     1798
# 3      109914   4911       487     1696
# 4      108458   5988       441     1544

# %%
df_test.head()
# Out:
#    Impression  Click  Purchase  Earning
# 0      120104   3217       702     1940
# 1      134776   3635       834     2929
# 2      107807   3057       423     2526
# 3      116445   4650       429     2281
# 4      145083   5201       750     2782

# %%
df_control.isnull().sum()
# Out:
# Impression    0
# Click         0
# Purchase      0
# Earning       0
# dtype: int64

# %%
df_test.isnull().sum()
# Out:
# Impression    0
# Click         0
# Purchase      0
# Earning       0
# dtype: int64

# %%
"""# Calculate average earnings for each group
avg_earning_control = df_control['Earning'].mean()  
avg_earning_test = df_test['Earning'].mean()
print(f'Average Earning (Control): {avg_earning_control:.2f}')
print(f'Average Earning (Test): {avg_earning_test:.2f}')

# Perform an independent samples t-test
t_stat, p_value = stats.ttest_ind(df_control['Earning'], df_test['Earning'])
print(f'T-statistic: {t_stat:.4f}')
print(f'P-value: {p_value:.4f}')

# Calculate effect size (Cohen's d)
pooled_std = ((len(df_control) - 1) * df_control['Earning'].std() ** 2 + (len(df_test) - 1) * df_test['Earning'].std() ** 2) / (len(df_control) + len(df_test) - 2)
cohens_d = (avg_earning_control - avg_earning_test) / (pooled_std ** 0.5)
print(f"Cohen's d: {cohens_d:.4f}")

# Visualize the results
labels = ['Control (Max Bidding)', 'Test (Avg Bidding)']    
earnings = [avg_earning_control, avg_earning_test]
plt.figure(figsize=(10, 6))
plt.bar(labels, earnings, color=['blue', 'orange'], alpha=0.7)
plt.ylabel('Average Earning')
plt.title('Average Earnings: Maximum Bidding vs Average Bidding')
plt.ylim(0, max(earnings) * 1.2)
for i, v in enumerate(earnings):
    plt.text(i, v + 50, f'${v:.2f}', ha='center', fontweight='bold')
plt.show()
"""
# Out:
# Average Earning (Control): 1908.58
# Average Earning (Test): 2514.93
# T-statistic: -9.2561
# P-value: 0.0000
# Cohen's d: -2.0697

# %% [markdown]
# ### Define the Null and Alternate hypothesis

# %% [markdown]
# In statistical hypothesis testing, the null hypothesis (H0) suppose that there is no significant effect, relationship, or difference in the variables being studied. It serves as a baseline assumption for statistical analysis. On the other hand, the alternative hypothesis (H1 or Ha) suggests the presence of a statistically significant effect, relationship, or difference. Researchers use hypothesis testing to evaluate the evidence against the null hypothesis, aiming to determine whether the observed data provides enough support to reject the null hypothesis in favor of the alternative. The interplay between these hypotheses forms the foundation for drawing conclusions in statistical analyses.
#
# <img src="Hypothesis.png" alt="Hypothesis" style="width:600px;">

# %% [markdown]
# ###  what would be the null and alternative hypothesis for this test?
#
# Null Hypothesis (H0): There is no significant difference between the average earnings of the two groups.
#
# Alternative Hypothesis (H1): There is a significant difference between the average earnings of the two groups.

# %% [markdown]
# Average bidding is test group
#
# Maximum bidding is control group
#
# so assined u1 and u2 to test and control group respectively
#
# case 1 :
#
# if u1>=u2 then we fail to reject null hypothesis it means there is no significant difference between the two groups in terms of average earnings. In other words, the average bidding strategy (test group) does not perform significantly better than the maximum bidding strategy (control group).
#
# if u1<u2 then we reject null hypothesis it means there is a significant difference between the two groups in terms of average earnings. In other words, the average bidding strategy (test group) performs significantly better than the maximum bidding strategy (control group).
#
# case 2:
#
# u1<=u2 then we fail to reject null hypothesis it means there is no significant difference between the two groups in terms of average earnings. In other words, the average bidding strategy (test group) does not perform significantly worse than the maximum bidding strategy (control group).
#
# if u1>u2 then we reject null hypothesis it means there is a significant difference between
#
# case 3:
#
# u1=u2 then we fail to reject null hypothesis it means there is no significant difference between the two groups in terms of average earnings. In other words, the average bidding strategy (test group) performs equally well as the maximum bidding strategy (control group).
#
# u1!=u2 then we reject null hypothesis it means there is a significant difference between the two groups in terms of average earnings. In other words, the average bidding strategy (test group) performs significantly differently than the maximum bidding strategy (control group).

# %% [markdown]
# ### Set the probability of type I and type II error

# %% [markdown]
# type 1 and type 2 errors
#
# type 1 error: rejecting the null hypothesis when it is actually true (false positive) it means in this case we would conclude that the average bidding strategy is better than the maximum bidding strategy when in reality there is no difference between the two strategies. This could lead to making changes based on incorrect conclusions, which may not yield the expected benefits.
#
# type 2 error: failing to reject the null hypothesis when it is actually false (false negative) it means in this case we would fail to conclude that the average bidding strategy is better than the maximum bidding strategy when in reality there is a significant difference between the two strategies. This could lead to missing out on potential improvements or making decisions based on incomplete information.

# %%
#calculate the skewness and kurtosis for the control  group
df_control_concat = pd.concat([df_control.describe().T,df_control.skew().rename('skewness'),df_control.kurtosis().rename('kurtosis')],axis=1)
print(df_control_concat)
# Out:
#             count        mean           std      min       25%      50%  \
# Impression   40.0  101711.450  20302.122984  45476.0  85726.75  99790.5
# Click        40.0    5100.625   1329.957772   2190.0   4124.25   5001.5
# Purchase     40.0     550.900    134.110517    267.0    470.50    531.5
# Earning      40.0    1908.575    302.868329   1254.0   1685.75   1975.0
#
#                  75%       max  skewness  kurtosis
# Impression  115212.5  147539.0 -0.001687  0.410967
# Click         5923.5    7959.0  0.179859 -0.436239
# Purchase       638.0     802.0 -0.026949 -0.571140
# Earning       2120.0    2497.0 -0.275640 -0.382968

# %% [markdown]
# The control group shows near-normal distribution across all metrics. Minor skewness indicates:
#
# A few higher click values (right tail in clicks)
# Slight clustering of higher earnings (left skew)
#
# Overall, the data is stable and well-balanced, with no strong bias or extreme outliers.

# %%
# calculate the skewness and kurtosis for the test group
df_test_concat = pd.concat([df_test.describe().T,df_test.skew().rename('skewness'),df_test.kurtosis().rename('kurtosis')],axis=1)
print(df_test_concat)
# Out:
#             count        mean           std      min        25%       50%  \
# Impression   40.0  120512.425  18807.466616  79034.0  112692.25  119291.5
# Click        40.0    3967.550    923.071766   1837.0    3376.50    3931.5
# Purchase     40.0     582.050    161.175164    312.0     444.75     551.0
# Earning      40.0    2514.925    282.707912   1940.0    2280.25    2544.5
#
#                   75%       max  skewness  kurtosis
# Impression  132050.75  158606.0 -0.185645  0.278201
# Click         4660.25    6020.0  0.098963  0.122631
# Purchase       699.75     890.0  0.228681 -1.020512
# Earning       2761.75    3171.0 -0.042370 -0.375022

# %% [markdown]
# The test group also maintains a fairly normal distribution, but with:
#
# Slight right skew in purchases → a few users making higher purchases
# Mild left skew in impressions → more observations clustered at higher values
#
# This suggests consistent performance with occasional high-value outcomes.

# %%
# analyze the skewness and kurtosis for the control group 
#plot the distribution of earnings for both groups
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.hist(df_control['Earning'], bins=30, color='blue', alpha=0.7)
plt.title('Earning Distribution - Control Group')
plt.xlabel('Earning')   
plt.ylabel('Frequency')
plt.subplot(1, 2, 2)
plt.hist(df_test['Earning'], bins=30, color='orange', alpha=0.7)
plt.title('Earning Distribution - Test Group')
plt.xlabel('Earning')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %%
# for Impression
impression_control_mean = df_control['Impression'].mean()
impression_test_mean = df_test['Impression'].mean()
impression_change = ((impression_test_mean - impression_control_mean) / impression_control_mean) * 100
#print(f'Impression - Control Mean: {impression_control_mean:.2f}, Test Mean: {impression_test_mean:.2f}, Change: {impression_change:.2f}%')
# for Click
click_control_mean = df_control['Click'].mean()
click_test_mean = df_test['Click'].mean()
click_change = ((click_test_mean - click_control_mean) / click_control_mean) * 100
#print(f'Click - Control Mean: {click_control_mean:.2f}, Test Mean: {click_test_mean:.2f}, Change: {click_change:.2f}%')
# for Purchase
purchase_control_mean = df_control['Purchase'].mean()
purchase_test_mean = df_test['Purchase'].mean()
purchase_change = ((purchase_test_mean - purchase_control_mean) / purchase_control_mean) * 100
#print(f'Purchase - Control Mean: {purchase_control_mean:.2f}, Test Mean: {purchase_test_mean:.2f}, Change: {purchase_change:.2f}%')
# for Earning
earning_control_mean = df_control['Earning'].mean()
earning_test_mean = df_test['Earning'].mean()
earning_change = ((earning_test_mean - earning_control_mean) / earning_control_mean) * 100
#print(f'Earning - Control Mean: {earning_control_mean:.2f}, Test Mean: {earning_test_mean:.2f}, Change: {earning_change:.2f}%')

# prepare a table for the above analysis
analysis_data = {
    'Metric': ['Impression', 'Click', 'Purchase', 'Earning'],
    'Control Mean': [impression_control_mean, click_control_mean, purchase_control_mean, earning_control_mean],
    'Test Mean': [impression_test_mean, click_test_mean, purchase_test_mean, earning_test_mean],
    'Change (%)': [impression_change, click_change, purchase_change, earning_change]
}
analysis_df = pd.DataFrame(analysis_data)
print(analysis_df)
# Out:
#        Metric  Control Mean   Test Mean  Change (%)
# 0  Impression    101711.450  120512.425   18.484620
# 1       Click      5100.625    3967.550  -22.214435
# 2    Purchase       550.900     582.050    5.654384
# 3     Earning      1908.575    2514.925   31.769776

# %% [markdown]
# on the above table analysis we can see that
#
# the test group has higer impression and it is 18% higher than the control group
#
# the click reduces in test group by 22% compared to control group
#
# the purchase increses in the test group by 5 % compared to control group
#
# the earning increases in the test group by 31% compared to control group

# %% [markdown]
# **funnel analysis**

# %% [markdown]
# define funnel analysis
#
# funnel analysis is a method used to track and analyze the steps that users take in a process, such as a sales or conversion funnel. It helps identify where users drop off and where improvements can be made to increase conversion rates. The funnel typically consists of several stages, such as awareness, interest, desire, and action, and the analysis focuses on understanding user behavior at each stage to optimize the overall process.

# %%
# for impression to click
impression_to_click_control = (click_control_mean / impression_control_mean) * 100
impression_to_click_test = (click_test_mean / impression_test_mean) * 100
print(f'Impression to Click - Control: {impression_to_click_control:.2f}%, Test: {impression_to_click_test:.2f}%') 
print('The test strategy is attracting more users but less relevant or less engaged traffic')

# for click to purchase
click_to_purchase_control = (purchase_control_mean / click_control_mean) * 100
click_to_purchase_test = (purchase_test_mean / click_test_mean) * 100
print(f'Click to Purchase - Control: {click_to_purchase_control:.2f}%, Test: {click_to_purchase_test:.2f}%')
print('Even though fewer users click, those who do are more likely to purchase → better targeting or intent.')

# for purchase to earning
purchase_to_earning_control = (earning_control_mean / purchase_control_mean) * 100
purchase_to_earning_test = (earning_test_mean / purchase_test_mean) * 100
print(f'Purchase to Earning - Control: {purchase_to_earning_control:.2f}%, Test: {purchase_to_earning_test:.2f}%')
print('the test strategy is generating more revenue per purchase, possibly due to higher-value purchases or better upselling.')
# Out:
# Impression to Click - Control: 5.01%, Test: 3.29%
# The test strategy is attracting more users but less relevant or less engaged traffic
# Click to Purchase - Control: 10.80%, Test: 14.67%
# Even though fewer users click, those who do are more likely to purchase → better targeting or intent.
# Purchase to Earning - Control: 346.45%, Test: 432.08%
# the test strategy is generating more revenue per purchase, possibly due to higher-value purchases or better upselling.

# %%
#calculate earning per click for both groups
earning_per_click_control = earning_control_mean / click_control_mean
earning_per_click_test = earning_test_mean / click_test_mean
print(f'Earning per Click - Control: ${earning_per_click_control:.2f}, Test: ${earning_per_click_test:.2f}')

# calculate earning per impression for both groups
earning_per_impression_control = earning_control_mean / impression_control_mean
earning_per_impression_test = earning_test_mean / impression_test_mean
print(f'Earning per Impression - Control: ${earning_per_impression_control:.4f}, Test: ${earning_per_impression_test:.4f}')

# calculate purchase per click for both groups
purchase_per_click_control = purchase_control_mean / click_control_mean
purchase_per_click_test = purchase_test_mean / click_test_mean
print(f'Purchase per Click - Control: {purchase_per_click_control:.4f}, Test: {purchase_per_click_test:.4f}')

# calculate earning per purchase for both groups
earning_per_purchase_control = earning_control_mean / purchase_control_mean
earning_per_purchase_test = earning_test_mean / purchase_test_mean
print(f'Earning per Purchase - Control: ${earning_per_purchase_control:.4f}, Test: ${earning_per_purchase_test:.4f}')
# Out:
# Earning per Click - Control: $0.37, Test: $0.63
# Earning per Impression - Control: $0.0188, Test: $0.0209
# Purchase per Click - Control: 0.1080, Test: 0.1467
# Earning per Purchase - Control: $3.4645, Test: $4.3208

# %% [markdown]
# earning per click is significantly higher in the test group, indicating that the average bidding strategy may be more effective at generating revenue from clicks compared to maximum bidding.
#
# earning per impression is slightly higher in the test group, suggesting that the average bidding strategy may be more efficient at generating revenue from impressions than maximum bidding.
#
# purchase per click is higher in the test group, indicating that the average bidding strategy may be more
#
# earning per purchase is higher in the test group, suggesting that the average bidding strategy may be generating higher-value purchases or better upselling compared to maximum bidding.

# %% [markdown]
# # Funnel Analysis Visaulization

# %%
import plotly.graph_objects as go
import plotly.express as px

# %%
# Add group labels
df_control["Group"] = "Control"
df_test["Group"] = "Test"

# Combine
df = pd.concat([df_control, df_test], ignore_index=True)

df.head()
# Out:
#    Impression  Click  Purchase  Earning    Group
# 0       82529   6090       665     2311  Control
# 1       98050   3383       315     1743  Control
# 2       82696   4168       458     1798  Control
# 3      109914   4911       487     1696  Control
# 4      108458   5988       441     1544  Control

# %% [markdown]
# **KPI Metrics**

# %%
summary = df.groupby("Group").agg({
    "Impression": "mean",
    "Click": "mean",
    "Purchase": "mean",
    "Earning": "mean"
}).reset_index()

summary
# Out:
#      Group  Impression     Click  Purchase   Earning
# 0  Control  101711.450  5100.625    550.90  1908.575
# 1     Test  120512.425  3967.550    582.05  2514.925

# %% [markdown]
# **Funnel Chart**

# %%
import plotly.graph_objects as go

fig_funnel = go.Figure()

for group in summary["Group"]:
    temp = summary[summary["Group"] == group]
    
    fig_funnel.add_trace(go.Funnel(
        name=group,
        y=["Impression", "Click", "Purchase", "Earning"],
        x=[
            temp["Impression"].values[0],
            temp["Click"].values[0],
            temp["Purchase"].values[0],
            temp["Earning"].values[0]
        ]
    ))

fig_funnel.update_layout(title="Funnel Comparison")
fig_funnel.show()

# %% [markdown]
# Metric Comparision

# %%
import plotly.express as px

summary_melt = summary.melt(id_vars="Group", var_name="Metric", value_name="Value")

fig_bar = px.bar(summary_melt,
                 x="Metric",
                 y="Value",
                 color="Group",
                 barmode="group",
                 title="Control vs Test Comparison")

fig_bar.show()

# %% [markdown]
# CTR = Click / Impression
#
# CVR = Purchase / Click

# %% [markdown]
# Conversion Metrics

# %%
summary["CTR"] = summary["Click"] / summary["Impression"]
summary["CVR"] = summary["Purchase"] / summary["Click"]

conv_df = summary.melt(id_vars="Group", value_vars=["CTR", "CVR"],
                       var_name="Metric", value_name="Rate")

fig_conv = px.bar(conv_df,
                  x="Metric",
                  y="Rate",
                  color="Group",
                  barmode="group",
                  title="Conversion Rates")

fig_conv.show()

# %% [markdown]
# Revenue Efficiency

# %%
summary["Revenue_per_Click"] = summary["Earning"] / summary["Click"]
summary["Revenue_per_Purchase"] = summary["Earning"] / summary["Purchase"]

rev_df = summary.melt(id_vars="Group",
                      value_vars=["Revenue_per_Click", "Revenue_per_Purchase"],
                      var_name="Metric", value_name="Value")

fig_rev = px.bar(rev_df,
                 x="Metric",
                 y="Value",
                 color="Group",
                 barmode="group",
                 title="Revenue Efficiency")

fig_rev.show()

# %%
fig_box = px.box(df,
                 x="Group",
                 y="Click",
                 title="Click Distribution by Group")

fig_box.show()

# %%
for _, row in summary.iterrows():
    print(f"""
    {row['Group']}:
    Impression: {row['Impression']:.0f}
    CTR: {row['CTR']:.2%}
    CVR: {row['CVR']:.2%}
    Revenue: {row['Earning']:.0f}
    """)
# Out:
#     Control:
#     Impression: 101711
#     CTR: 5.01%
#     CVR: 10.80%
#     Revenue: 1909
#
#
#     Test:
#     Impression: 120512
#     CTR: 3.29%
#     CVR: 14.67%
#     Revenue: 2515

# %% [markdown]
# ### Sample size
#
# Z = (norm.ppf(1-(alpha/2)) + norm.ppf(1-beta))**2

# %% [markdown]
# Where
#
# - $n$ = required sample size per group
# - $p$ = average conversion rate = $\frac{p_1 + p_2}{2}$
# - $p_1$ = baseline conversion rate (control group)
# - $p_2$ = expected conversion rate (test group)
# - $(p_1 - p_2)$ = minimum detectable effect (MDE)
# - $Z_{\alpha/2}$ = critical value for significance level (e.g., 1.96 for α = 0.05)
# - $Z_{\beta}$ = critical value for power (e.g., 0.84 for 80% power)

# %%
# calculate the sample size 
from scipy.stats import norm
import numpy as np
alpha = 0.05
beta = 0.2
Z = (norm.ppf(1-(alpha/2), loc=0, scale=1) + norm.ppf(1-beta, loc=0, scale=1))**2
var = pd.concat([df_control['Earning'],df_test['Earning']]).var()
expected_effect_size = 200

sample_size = (Z*2*var)/(expected_effect_size**2)

print(sample_size.astype('int'))
# Out:
# 69

# %%
import pandas as pd
from scipy.stats import levene
from scipy.stats import ttest_ind

mean_control = df_control['Earning'].mean()
mean_test = df_test['Earning'].mean()

print("mean_control=", mean_control)
print("mean_test=",mean_test)

# Perform two-sample t-test for each level of 'pathsize_cat'
groupC = df_control['Earning']
groupT = df_test['Earning']
    
# Perform Levene's test for homogeneity of variances
statistic, p_value_L = levene(groupC, groupT)

if  p_value_L > 0.05:

    t_statistic, p_value = ttest_ind(groupC, groupT,alternative="less" ,equal_var=True)

    print("t-statistic:", t_statistic)
    print("p-value:", p_value)

else:
        
    t_statistic, p_value = ttest_ind(groupC, groupT,alternative="less", equal_var=False)

    print("t-statistic:", t_statistic)
    print("p-value:", p_value)    
    
# Determine significance
alpha = 0.05
if p_value < alpha:
    print("Reject the null hypothesis: There is a significant difference between the means.")
else:
    print("Fail to reject the null hypothesis: There is no significant difference between the means.")
print("\n")
# Out:
# mean_control= 1908.575
# mean_test= 2514.925
# t-statistic: -9.256092651165002
# p-value: 1.720180077421263e-14
# Reject the null hypothesis: There is a significant difference between the means.

# %% [markdown]
# Confidence Interval

# %%
import numpy as np

def bootstrap_ci(control, test, n_boot=5000):
    diffs = []
    for _ in range(n_boot):
        c = np.random.choice(control, size=len(control), replace=True)
        t = np.random.choice(test, size=len(test), replace=True)
        diffs.append(np.mean(t) - np.mean(c))
    return np.percentile(diffs, [2.5, 97.5])

ci = bootstrap_ci(df_control['Earning'].values, df_test['Earning'].values)

print("95% Confidence Interval (Test - Control):", ci)
# Out:
# 95% Confidence Interval (Test - Control): [478.07    728.27875]

# %% [markdown]
# “We are 95% confident that the new strategy increases earnings by ₹478 to ₹728 per user.”
